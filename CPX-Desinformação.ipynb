# %%
#Resultados da API para o YouTube sobre CPX

# %%
# Importa a biblioteca do Google API
from googleapiclient.discovery import build
import csv

# Define a chave de API do YouTube
API_KEY = 'AIzaSyCF7hR7cl_7fxcTxYozwMpcUDhVzmJP95o'

# Define o nome do canal que você deseja pesquisar
query = 'CPX'

# Define a data mínima de publicação (agosto de 2022)
min_date = '2022-08-01T00:00:00Z'

# Cria um objeto do YouTube Data API v3
youtube = build('youtube', 'v3', developerKey=API_KEY)

# Faz a pesquisa usando o método search.list do YouTube Data API v3
search_response = youtube.search().list(
    q=query,
    type='video',
    publishedAfter=min_date,
    order='viewCount',
    maxResults=100,
    part='id,snippet',
).execute()

# Cria uma lista para armazenar as informações dos vídeos
videos = []

# Percorre os resultados da pesquisa
for search_result in search_response.get('items', []):
    # Obtém informações adicionais sobre o vídeo usando o método videos.list do YouTube Data API v3
    video_response = youtube.videos().list(
        id=search_result['id']['videoId'],
        part='snippet,statistics',
    ).execute()
    
    # Extrai as informações relevantes do resultado da pesquisa e do resultado do vídeo
    title = video_response['items'][0]['snippet']['title']
    channel_title = video_response['items'][0]['snippet']['channelTitle']
    view_count = video_response['items'][0]['statistics']['viewCount']
    comment_count = video_response['items'][0]['statistics'].get('commentCount', 0)
    published_date = video_response['items'][0]['snippet']['publishedAt']
    
    # Adiciona as informações do vídeo à lista
    videos.append([title, channel_title, view_count, comment_count, published_date])
    
# Cria e escreve os dados em um arquivo CSV
with open('videos.csv', mode='w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL, lineterminator='\n')
    writer.writerow(['Título', 'Canal', 'Acessos', 'Comentários', 'Data de publicação'])
    for video in videos:
        writer.writerow(video)

# Lê e exibe o conteúdo do arquivo CSV
with open('videos.csv', mode='r', encoding='utf-8') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        print(row)
# Out:
# ['Título', 'Canal', 'Acessos', 'Comentários', 'Data de publicação']
# ['Sigla CPX oque significa?', 'Léo Camarinho', '1914070', '2639', '2022-10-28T20:00:08Z']
# ['CPX DOS CRIAS - Podpah de Verão #542', 'Podpah', '1444029', '353', '2023-01-23T22:08:04Z']
# ['Major Felipe Sommer do Bope explica o que significa CPX', 'Olhar Cidade', '921425', '2343', '2022-10-26T00:42:59Z']
# ['(GTARP) MOTIVO DA PRISÃO: "AQUI É O PAAAAULO!!!" - CPX', '5segundos', '805290', '64', '2022-11-11T15:00:12Z']
# ['ME INFILTREI NA F@V3LA DA MILÍCIA no GTA RP 😂 (Clips da LIVE) (Paulinho O LOKO)', 'Modder Clips [OFICIAL]', '815322', '289', '2023-03-29T23:00:25Z']
# ['Censura do TSE à JP /Lula e o CPX / padre lacrador / Amoêdo apoia Lula - 4por4, 16/10/22', 'Programa 4 por 4', '423486', '159', '2022-10-17T04:56:33Z']
# ['RED MATOU  O PAULINHO DA MONTANHA DE SNIPER * GTA RP CPX * #shorts', 'CORTESMANIAGTARP', '391726', '210', '2023-03-08T09:28:44Z']
# ...

# %%
import pandas as pd
import numpy as np
import urllib
import requests
import io
import lxml
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Lê o arquivo CSV e armazena em um dataframe
df = pd.read_csv('videos.csv', encoding='utf-8')
print(df.head(101))
# Out:
#                                                Título  \
# 0                           Sigla CPX oque significa?
# 1                CPX DOS CRIAS - Podpah de Verão #542
# 2   Major Felipe Sommer do Bope explica o que sign...
# 3   (GTARP) MOTIVO DA PRISÃO: "AQUI É O PAAAAULO!!...
# 4   ME INFILTREI NA F@V3LA DA MILÍCIA no GTA RP 😂 ...
# 5   Censura do TSE à JP /Lula e o CPX / padre lacr...
# 6   RED MATOU  O PAULINHO DA MONTANHA DE SNIPER * ...
# 7   BONÉ “CPX” DE LULA GERA POLÊMICA - MORNING SHO...
# 8   CPX DOS CRIAS NO PODPAH DE VERÃO - MELHORES MO...
# 9     ASSIM QUE O C*V TOMOU O CPX DO ALEMÃO, ATÉ QUE…
# 10  RED CONSEGUIU A MELHOR VINGANÇA CONTRA O PAULI...
# 11                                  零九 Plus CPX 遠離塵囂篇
# 12  EU M4T3I O DONO DO CPX DA PEDREIRA E... | CARE...
# 13                  TSE tira o boné CPX que Lula usou
# 14  [CPX] #Bafocalipse EU PAULINHO LOKO E RED INVA...
# 15  MC HULK - O BONDE DO ABELHA TA AQUI ( DJ LZ Do...
# ...

# %%
df_sorted = df.sort_values('Comentários', ascending=False)
print(df_sorted)
# Out:
#                                                Título  \
# 0                           Sigla CPX oque significa?
# 13                  TSE tira o boné CPX que Lula usou
# 2   Major Felipe Sommer do Bope explica o que sign...
# 30  Lula usa boné com sigla 'CPX' e vira alvo de f...
# 23  TROPA DO SAPO E DEMONIKE INVADIU A GROTA E BEC...
# 34         Boné de Lula com sigla “CPX” gera polêmica
# 7   BONÉ “CPX” DE LULA GERA POLÊMICA - MORNING SHO...
# 21  HIGHLIGHTS LUQUET4 o PATRÃO DA GROTA! #1 (100%...
# 19  DJ Noiskita - CPX Ta Tega (Música Oficial Comp...
# 48  GUERRA MILICIA x GROTA NO NORTE 22 x 22 ! A GU...
# 16  'CPX': o que significa sigla em boné de Lula, ...
# 41  É falso que sigla CPX, no boné de Lula, seja r...
# 39  Fivem Highlights RaroXT #87 🐱‍👤 ( 100%CPX  ) "...
# 32  Major do BOPE: CPX significa cupinxa - parceri...
# 35  Lula alvo de fake por boné 'CPX', fala de Bols...
# 42              CPX no BONÉ DE LULA! O QUE SIGNIFICA?
# ...

# %%
import pandas as pd

# Lê o arquivo CSV e armazena em um dataframe
df = pd.read_csv('videos.csv', encoding='utf-8')

# Ordena o dataframe por número de comentários
df_sorted = df.sort_values('Comentários', ascending=False)

# Exibe a tabela em html com fundo em escala de cinza e branco
display(df_sorted.style.background_gradient(cmap='Greys'))
# Out:
# <style  type="text/css" >
# #T_8dce7_row0_col2,#T_8dce7_row0_col3{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_8dce7_row1_col2,#T_8dce7_row24_col3,#T_8dce7_row25_col3,#T_8dce7_row26_col3{
#             background-color:  #f6f6f6;
#             color:  #000000;
#         }#T_8dce7_row1_col3{
#             background-color:  #101010;
#             color:  #f1f1f1;
#         }#T_8dce7_row2_col2{
#             background-color:  #a2a2a2;
#             color:  #000000;
#         }#T_8dce7_row2_col3{
#             background-color:  #212121;
#             color:  #f1f1f1;
#         }#T_8dce7_row3_col2,#T_8dce7_row37_col3,#T_8dce7_row38_col3,#T_8dce7_row39_col3,#T_8dce7_row40_col3,#T_8dce7_row47_col2{
#             background-color:  #fdfdfd;
#             color:  #000000;
#         }#T_8dce7_row3_col3{
#             background-color:  #4b4b4b;
#             color:  #f1f1f1;
# ...

# %%
import pandas as pd

# Lê o arquivo CSV e armazena em um dataframe
df = pd.read_csv('videos.csv', encoding='utf-8')

# Ordena o dataframe por número de acessos
df_sorted = df.sort_values('Acessos', ascending=False)

# Define uma função para aplicar a formatação nas linhas alternadas
def alternating_rows(row):
    if row.name % 2 == 0:
        return ['background-color: #F2F2F2'] * len(row)
    else:
        return [''] * len(row)

# Aplica a função na tabela
styled_table = df_sorted.style.apply(alternating_rows, axis=1)

# Exibe a tabela em html
styled_table
# Out:
# <style  type="text/css" >
# ...

# %%
# Lê o arquivo CSV e armazena em um dataframe
df = pd.read_csv('videos.csv', encoding='utf-8')
df = df[~df['Título'].str.contains('GTA', regex=False)]
# Ordena o dataframe por número de acessos
df_sorted = df.sort_values('Acessos', ascending=False)

# Define uma função para aplicar a formatação nas linhas alternadas
def alternating_rows(row):
    if row.name % 2 == 0:
        return ['background-color: #F2F2F2'] * len(row)
    else:
        return [''] * len(row)

# Aplica a função na tabela
styled_table = df_sorted.style.apply(alternating_rows, axis=1)

# Exibe a tabela em html
styled_table
# Out:
# <style  type="text/css" >
# ...

# %%
# Lê o arquivo CSV e armazena em um dataframe
df = pd.read_csv('videos.csv', encoding='utf-8', nrows=100)
df = df[~df['Título'].str.contains('GTA', regex=False)]
# Ordena o dataframe por número de acessos
df_sorted = df.sort_values('Acessos', ascending=False)

# Define uma função para aplicar a formatação nas linhas alternadas
def alternating_rows(row):
    if row.name % 2 == 0:
        return ['background-color: #F2F2F2'] * len(row)
    else:
        return [''] * len(row)

# Aplica a função na tabela
styled_table = df_sorted.style.apply(alternating_rows, axis=1)

# Exibe a tabela em html
styled_table
# Out:
# <style  type="text/css" >
# ...

# %%
import csv

# Define a chave de API do YouTube
API_KEY = 'AIzaSyCF7hR7cl_7fxcTxYozwMpcUDhVzmJP95o'

# Define o nome do canal que você deseja pesquisar
query = 'CPX Lula'

# Define a data mínima de publicação (agosto de 2022)
min_date = '2022-08-01T00:00:00Z'

# Cria um objeto do YouTube Data API v3
youtube = build('youtube', 'v3', developerKey=API_KEY)

# Faz a pesquisa usando o método search.list do YouTube Data API v3
search_response = youtube.search().list(
    q=query,
    type='video',
    publishedAfter=min_date,
    order='viewCount',
    maxResults=100,
    part='id,snippet',
).execute()

# Cria uma lista para armazenar as informações dos vídeos
videos = []

# Percorre os resultados da pesquisa
for search_result in search_response.get('items', []):
    # Obtém informações adicionais sobre o vídeo usando o método videos.list do YouTube Data API v3
    video_response = youtube.videos().list(
        id=search_result['id']['videoId'],
        part='snippet,statistics',
    ).execute()
    
    # Extrai as informações relevantes do resultado da pesquisa e do resultado do vídeo
    title = video_response['items'][0]['snippet']['title']
    channel_title = video_response['items'][0]['snippet']['channelTitle']
    view_count = video_response['items'][0]['statistics']['viewCount']
    comment_count = video_response['items'][0]['statistics'].get('commentCount', 0)
    published_date = video_response['items'][0]['snippet']['publishedAt']
    
    # Adiciona as informações do vídeo à lista
    videos.append([title, channel_title, view_count, comment_count, published_date])
    
# Cria e escreve os dados em um arquivo CSV com o nome "videoslulacpx.csv"
with open('videoslulacpx.csv', mode='w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL, lineterminator='\n')
    writer.writerow(['Título', 'Canal', 'Acessos', 'Comentários', 'Data de publicação'])
    for video in videos:
        writer.writerow(video)

# Lê e exibe os dados do arquivo CSV
import pandas as pd

df = pd.read_csv('videoslulacpx.csv', encoding='utf-8')
print(df)
# Out:
#                                                Título  \
# 0   LULA PROVOCA NEYMAR E CITA DÍVIDA: 'ELE TEM MEDO'
# 1   Major Felipe Sommer do Bope explica o que sign...
# 2   MARCO ANTONIO DETONA DISCURSO DE LULA NO COMPL...
# 3   Nikolas Ferreira mostra participação do ex-pre...
# 4   Censura do TSE à JP /Lula e o CPX / padre lacr...
# 5   BONÉ “CPX” DE LULA GERA POLÊMICA - MORNING SHO...
# 6                   TSE tira o boné CPX que Lula usou
# 7   'CPX': o que significa sigla em boné de Lula, ...
# 8       Lula recebe apoio no Complexo do Alemão | AFP
# 9   Fake news associa Lula ao tráfico de drogas #s...
# 10  Lula usa boné com sigla 'CPX' e vira alvo de f...
# 11       SIGNIFICADO DO BONÉ DE LULA COM INICIAIS CPX
# 12  Bolsonaro diz que Lula teve 'só traficantes' a...
# 13     CPX - Transferência de Marcola no Governo Lula
# 14         Boné de Lula com sigla “CPX” gera polêmica
# 15  Lula alvo de fake por boné 'CPX', fala de Bols...
# ...

# %%
import pandas as pd
import csv

# Lê o arquivo CSV e armazena em um dataframe
df = pd.read_csv('videoslulacpx.csv', encoding='utf-8', nrows=100)
df = df[~df['Título'].str.contains('GTA', regex=False)]

# Ordena o dataframe por número de acessos
df_sorted = df.sort_values('Acessos', ascending=False)

# Define uma função para aplicar a formatação nas linhas alternadas
def alternating_rows(row):
    if row.name % 2 == 0:
        return ['background-color: #F2F2F2'] * len(row)
    else:
        return [''] * len(row)

# Aplica a função na tabela
styled_table = df_sorted.style.apply(alternating_rows, axis=1)

# Cria um novo dataframe chamado lilsdf com as colunas Título, Canal e Acessos
lilsdf = df_sorted[['Título', 'Canal', 'Acessos']]

# Aplica a função na tabela lilsdf
styled_lilsdf = lilsdf.style.apply(alternating_rows, axis=1)

# Exibe a tabela em html
stlils = styled_lilsdf.render()

# Exibe a tabela estilizada
display(styled_table)
# Out:
# <style  type="text/css" >
# ...
